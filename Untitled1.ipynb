# %%
# !pip install okama
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.0/74.0 kB 3.5 MB/s eta 0:00:00
# ...

# %%
import matplotlib. pyplot as plt
plt.rcParams['figure.figsize']= [12.0, 6.0]
import okama as ok

# %%
x= ok.AssetList(['LKOH.MOEX', 'SNGSP.MOEX'], ccy='RUB')

# %%
x
# Out:
# assets           [LKOH.MOEX, SNGSP.MOEX]
# currency                             RUB
# first_date                       2003-09
# last_date                        2023-05
# period_length         19 years, 9 months
# inflation                       RUB.INFL
# dtype: object

# %%
x.dividends_annual. plot(kind='bar');

# %%
x.dividends_annual['SNGSP.MOEX']. plot(kind='bar');

# %%
x.assets_dividend_yield.tail(20)
# Out:
#          LKOH.MOEX  SNGSP.MOEX
# 2021-10   0.035776    0.173981
# 2021-11   0.039296    0.179104
# 2021-12   0.084170    0.174636
# 2022-01   0.080972    0.180088
# 2022-02   0.112376    0.225163
# 2022-03   0.097359    0.182857
# 2022-04   0.117672    0.201953
# 2022-05   0.136157    0.190072
# 2022-06   0.141613    0.192275
# 2022-07   0.087697    0.161158
# 2022-08   0.079625    0.163216
# 2022-09   0.087023    0.219490
# 2022-10   0.072634    0.184370
# 2022-11   0.073945    0.190572
# 2022-12   0.194721    0.182274
# 2023-01   0.200303    0.169170
# 2023-02   0.200000    0.169960
# 2023-03   0.181922    0.148276
# 2023-04   0.169083    0.134394
# 2023-05   0.142242    0.150302

# %%
x.assets_dividend_yield.plot()
# Out:
# <Axes: >

# %%
x.get_dividend_mean_growth_rate(period=10)
# Out:
# LKOH.MOEX     0.212991
# SNGSP.MOEX    0.082037
# dtype: float64

# %%
x.dividend_paying_years
# Out:
#       LKOH.MOEX  SNGSP.MOEX
# 2003          0           0
# 2004          1           1
# 2005          2           2
# 2006          3           3
# 2007          4           4
# 2008          5           5
# 2009          6           6
# 2010          7           7
# 2011          8           8
# 2012          9           9
# 2013         10          10
# 2014         11          11
# 2015         12          12
# 2016         13          13
# 2017         14          14
# 2018         15          15
# 2019         16          16
# 2020         17          17
# 2021         18          18
# 2022         19          19
# 2023          0           0

# %%
x.dividend_paying_years.plot()
# Out:
# <Axes: >

# %%
x.dividend_growing_years
# Out:
#       LKOH.MOEX  SNGSP.MOEX
# 2004          1           1
# 2005          2           2
# 2006          3           3
# 2007          4           0
# 2008          5           1
# 2009          6           2
# 2010          7           0
# 2011          8           1
# 2012          9           2
# 2013          0           0
# 2014          1           1
# 2015          2           2
# 2016          3           0
# 2017          4           0
# 2018          5           1
# 2019          6           2
# 2020          7           0
# 2021          8           1
# 2022          9           0
# 2023          0           0

# %%
x.dividend_growing_years.plot()
# Out:
# <Axes: >

# %%
y=ok.AssetList(['JNJ.US','MSFT.US'],ccy='USD')

# %%
y.dividends_annual.plot(kind='bar');

# %%
y.assets_dividend_yield.plot()
# Out:
# <Axes: >

# %%
y.get_dividend_mean_growth_rate(period=10)
# Out:
# JNJ.US     0.063690
# MSFT.US    0.118344
# dtype: float64

# %%
y.dividend_paying_years
# Out:
#       JNJ.US  MSFT.US
# 1986       0        0
# 1987       0        0
# 1988       0        0
# 1989       0        0
# 1990       1        0
# 1991       2        0
# 1992       3        0
# 1993       4        0
# 1994       5        0
# 1995       6        0
# 1996       7        0
# 1997       8        0
# 1998       9        0
# 1999      10        0
# 2000      11        0
# 2001      12        0
# 2002      13        0
# 2003      14        1
# 2004      15        2
# 2005      16        3
# 2006      17        4
# 2007      18        5
# 2008      19        6
# 2009      20        7
# 2010      21        8
# 2011      22        9
# 2012      23       10
# 2013      24       11
# 2014      25       12
# 2015      26       13
# 2016      27       14
# 2017      28       15
# 2018      29       16
# 2019      30       17
# 2020      31       18
# 2021      32       19
# 2022      33       20
# 2023      34       21

# %%
y.dividend_growing_years
# Out:
#       JNJ.US  MSFT.US
# 1987       0        0
# 1988       0        0
# 1989       0        0
# 1990       1        0
# 1991       2        0
# 1992       3        0
# 1993       4        0
# 1994       5        0
# 1995       6        0
# 1996       7        0
# 1997       8        0
# 1998       9        0
# 1999      10        0
# 2000      11        0
# 2001      12        0
# 2002      13        0
# 2003      14        1
# 2004      15        2
# 2005      16        0
# 2006      17        1
# 2007      18        2
# 2008      19        3
# 2009      20        4
# 2010      21        5
# 2011      22        6
# 2012      23        7
# 2013      24        8
# 2014      25        9
# 2015      26       10
# 2016      27       11
# 2017      28       12
# 2018      29       13
# 2019      30       14
# 2020      31       15
# 2021      32       16
# 2022      33       17
# 2023       0        0
